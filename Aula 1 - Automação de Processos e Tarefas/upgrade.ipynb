# %% [markdown]
# # Upgrade Aula 1 by luizalaquini
#
# Upgrade do código da aula 1 após conteúdo visto na aula 3

# %%
from selenium import webdriver # controla o navegador
from selenium.webdriver.common.keys import Keys # controla o teclado
from selenium.webdriver.common.by import By # localizar os itens no navegador
import time

# Passo 1 - Abrir o navegador e entrar no sistema (no nosso caso, entrar no link do drive)
navegador = webdriver.Chrome()
navegador.get("https://drive.google.com/drive/folders/14oLE59U1RqyRqlBbKpsyymW-mitvbtoh")
time.sleep(3) # espera carregar

# Passo 2: Baixar o arquivo de dados
navegador.find_element(By.XPATH, '//*[@id=":0"]/div/c-wiz/div[2]/c-wiz/div[1]/c-wiz/div/c-wiz/div[1]/c-wiz/c-wiz/div/c-wiz/div/div/div/div[1]/div[2]').click()
time.sleep(3) # espera carregar

navegador.quit() # fecha navegador com o webdriver

# %%
# Passo 3: Ler o arquivo para pegar o indicadores (Faturamento e Quantidade de Produtos)
import pandas as pd
from IPython.display import display

tabela = pd.read_excel(r'C:\Users\luiza\Downloads\Vendas - Dez.xlsx') # o "r" significa "row string" e faz com que o programa desconsidere caracteres especiais 
display(tabela)
faturamento = tabela["Valor Final"].sum()
quantidade = tabela["Quantidade"].sum()
# Out:
#       Código Venda       Data                     ID Loja           Produto  \
# 0            65014 2019-12-01            Shopping Morumbi    Sunga Listrado
# 1            65014 2019-12-01            Shopping Morumbi   Casaco Listrado
# 2            65016 2019-12-01           Iguatemi Campinas   Sapato Listrado
# 3            65016 2019-12-01           Iguatemi Campinas            Casaco
# 4            65017 2019-12-01          Shopping SP Market        Gorro Liso
# ...            ...        ...                         ...               ...
# 7084         69996 2019-12-26  Center Shopping Uberlândia    Short Listrado
# 7085         69996 2019-12-26  Center Shopping Uberlândia           Mochila
# 7086         69996 2019-12-26  Center Shopping Uberlândia  Pulseira Estampa
# 7087         69997 2019-12-26           Ribeirão Shopping   Camisa Listrado
# 7088         69997 2019-12-26           Ribeirão Shopping       Short Linho
#
#       Quantidade  Valor Unitário  Valor Final
# ...

# %%
# Passo 4: ENTRAR NO GMAIL COM PYAUTOGUI JÁ QUE O CHOME NÃO PERMITE ACESSO COM O WEBDRIVER (NÃO-SEGURO).

import pyautogui as pag
import pyperclip as ppc

pag.PAUSE = 1.5 # Pausa que vai ser dada entre cada instrução

pag.press("win")
pag.write("chrome")
pag.press("enter")
ppc.copy("https://mail.google.com/mail/u/0/#inbox")
pag.hotkey("ctrl", "v")
pag.press("enter")
time.sleep(4) # espera carregar 

# Passo 5 Enviar um email para a diretoria (no caso, eu mesma)
pag.press("c") # atalho novo email
ppc.copy("luizablaquini@gmail.com")
pag.hotkey("ctrl", "v")
pag.press("tab") # pula para o campo de assunto
ppc.copy("Relatório mensal de Vendas [DEZEMBRO]")
pag.hotkey("ctrl", "v")
pag.press("tab") # pula para o campo da mensagem

texto = f"""Bom dia

Relativo ao mês de DEZEMBRO:

O faturamento do mês foi de: R${faturamento:,.2f}
A quantidade de produtos vendida foi de: {quantidade:,}

Abs
Att: Luiza B Laquini
"""

ppc.copy(texto)
pag.hotkey("ctrl", "v")
pag.press("tab") # pula para o botão de enviar
pag.press("enter")
pag.hotkey("ctrl", "w") # fecha aba
